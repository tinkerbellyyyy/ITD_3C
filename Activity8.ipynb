# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folium in c:\users\regine salva\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (0.19.5)
# Requirement already satisfied: branca>=0.6.0 in c:\users\regine salva\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\regine salva\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\regine salva\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from folium) (2.2.5)
# Requirement already satisfied: requests in c:\users\regine salva\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\regine salva\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\regine salva\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\regine salva\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\regine salva\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\regine salva\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->folium) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\regine salva\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->folium) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Load the dataset with the correct encoding
df = pd.read_csv('Datasets\\Global_terrorist.csv', encoding = 'ISO-8859-1')

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# 0            58  Dominican Republic       2  ...      NaN
# 1           130              Mexico       1  ...      NaN
# 2           160         Philippines       5  ...      NaN
# 3            78              Greece       8  ...      NaN
# 4           101               Japan       4  ...      NaN
# ...         ...                 ...     ...  ...      ...
# 181686      182             Somalia      11  ...      NaN
# 181687      200               Syria      10  ...      NaN
# 181688      160         Philippines       5  ...      NaN
# 181689       92               India       6  ...      NaN
# 181690      160         Philippines       5  ...      NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS        0         0        0       0      NaN
# 1                           PGIS        0         1        1       1      NaN
# 2                           PGIS       -9        -9        1       1      NaN
# 3                           PGIS       -9        -9        1       1      NaN
# 4                           PGIS       -9        -9        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [181691 rows x 135 columns]

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# <h1>Filtering Data</h1>

# %%
df['region_txt'].unique()
# Out:
# array(['Central America & Caribbean', 'North America', 'Southeast Asia',
#        'Western Europe', 'East Asia', 'South America', 'Eastern Europe',
#        'Sub-Saharan Africa', 'Middle East & North Africa',
#        'Australasia & Oceania', 'South Asia', 'Central Asia'],
#       dtype=object)

# %%
filter1 = df[df['region_txt'] == 'Middle East & North Africa']

# %%
filter1
# Out:
#              eventid  iyear  imonth  iday           approxdate  extended  \
# 95      197002280001   1970       2    28                  NaN         0
# 133     197003140002   1970       3    14                  NaN         0
# 158     197003290002   1970       3    29                  NaN         0
# 195     197004150001   1970       4    15                  NaN         0
# 226     197004250001   1970       4    25                  NaN         0
# ...              ...    ...     ...   ...                  ...       ...
# 181670  201712310003   2017      12    31  2017-12-31 00:00:00         0
# 181671  201712310004   2017      12    31                  NaN         0
# 181674  201712310007   2017      12    31                  NaN         0
# 181679  201712310012   2017      12    31                  NaN         0
# 181687  201712310029   2017      12    31                  NaN         0
#
#        resolution  country country_txt  region  ...  \
# 95            NaN      102      Jordan      10  ...
# 133           NaN       60       Egypt      10  ...
# 158           NaN      110     Lebanon      10  ...
# 195           NaN      102      Jordan      10  ...
# 226           NaN      209      Turkey      10  ...
# ...           ...      ...         ...     ...  ...
# 181670        NaN       95        Iraq      10  ...
# 181671        NaN       95        Iraq      10  ...
# 181674        NaN       95        Iraq      10  ...
# 181679        NaN       95        Iraq      10  ...
# 181687        NaN      200       Syria      10  ...
#
#                                                  addnotes  \
# 95                                                    NaN
# 133                                                   NaN
# 158                                                   NaN
# 195                                                   NaN
# 226                                                   NaN
# ...                                                   ...
# 181670                                                NaN
# 181671  Casualty numbers conflict across sources. Foll...
# 181674                                                NaN
# 181679                                                NaN
# 181687                                                NaN
#
#                                                    scite1  \
# 95                                                    NaN
# 133                                                   NaN
# 158                                                   NaN
# 195                                                   NaN
# 226                                                   NaN
# ...                                                   ...
# 181670  "Iraq: Security Roundup 1900 GMT 31 December 2...
# 181671  "Islamic State attack leaves thirteen civilian...
# 181674  "Five IS militants killed as paramilitary troo...
# 181679  "13 IS militants killed in attack on paramilit...
# 181687  "Putin's 'victory' in Syria has turned into a ...
#
#                                                    scite2  \
# 95                                                    NaN
# 133                                                   NaN
# 158                                                   NaN
# 195                                                   NaN
# 226                                                   NaN
# ...                                                   ...
# 181670  "Terrorism: Roundup of Official ISIS Messages ...
# 181671  "3 people killed in IS attack in central Iraq,...
# 181674  "1,262 Killed in Iraq During December," Antiwa...
# 181679                                                NaN
# 181687  "Two Russian soldiers killed at Hmeymim base i...
#
#                                                    scite3  \
# 95                                                    NaN
# 133                                                   NaN
# 158                                                   NaN
# 195                                                   NaN
# 226                                                   NaN
# ...                                                   ...
# 181670                                                NaN
# 181671  "Daesh gunmen kill 3 in northern Iraq: Police,...
# 181674                                                NaN
# 181679                                                NaN
# 181687  "Two Russian servicemen killed in Syria mortar...
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 95                          PGIS       -9        -9        0      -9      NaN
# 133                         PGIS       -9        -9        0      -9      NaN
# 158                         PGIS        0         1        1       1      NaN
# 195                         PGIS        0         1        1       1      NaN
# 226                         PGIS        1         0        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181670  START Primary Collection        0         1        0       1      NaN
# 181671  START Primary Collection        0         1        0       1      NaN
# 181674  START Primary Collection        0         1        0       1      NaN
# 181679  START Primary Collection        0         1        0       1      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
#
# [50474 rows x 135 columns]

# %%
filter1['attacktype1_txt'].unique()
# Out:
# array(['Armed Assault', 'Bombing/Explosion', 'Unknown',
#        'Hostage Taking (Kidnapping)',
#        'Hostage Taking (Barricade Incident)', 'Assassination',
#        'Hijacking', 'Facility/Infrastructure Attack', 'Unarmed Assault'],
#       dtype=object)

# %%
filter2 = filter1[filter1['attacktype1_txt'] == 'Bombing/Explosion']

# %%
filter2['nkill']
# Out:
# 133       0.0
# 158       0.0
# 195       0.0
# 226       0.0
# 334       NaN
#          ...
# 181667    NaN
# 181668    0.0
# 181669    0.0
# 181671    4.0
# 181687    2.0
# Name: nkill, Length: 30908, dtype: float64

# %%
filter2[filter2['nkill'] >=10]
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 1314    197205300001   1972       5    30        NaN         0        NaN
# 2382    197405180001   1974       5    18        NaN         0        NaN
# 4385    197612150001   1976      12    15        NaN         0        NaN
# 6607    197808130002   1978       8    13        NaN         0        NaN
# 8700    197906160007   1979       6    16        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 180708  201711240001   2017      11    24        NaN         0        NaN
# 180811  201711270007   2017      11    27        NaN         0        NaN
# 180942  201712010003   2017      12     1        NaN         0        NaN
# 181537  201712250023   2017      12    25        NaN         0        NaN
# 181624  201712290002   2017      12    29        NaN         0        NaN
#
#         country country_txt  region  ...  \
# 1314         97      Israel      10  ...
# 2382         97      Israel      10  ...
# 4385         95        Iraq      10  ...
# 6607        110     Lebanon      10  ...
# 8700        200       Syria      10  ...
# ...         ...         ...     ...  ...
# 180708       60       Egypt      10  ...
# 180811       95        Iraq      10  ...
# 180942       95        Iraq      10  ...
# 181537      228       Yemen      10  ...
# 181624       60       Egypt      10  ...
#
#                                                  addnotes  \
# 1314                                                  NaN
# 2382                                                  NaN
# 4385                                                  NaN
# 6607                                                  NaN
# 8700                                                  NaN
# ...                                                   ...
# 180708  Casualty numbers conflict across sources. Foll...
# 180811  Casualty numbers conflict across sources. Foll...
# 180942                                                NaN
# 181537                                                NaN
# 181624  Casualty numbers conflict across sources. Foll...
#
#                                                    scite1  \
# 1314                                                  NaN
# 2382                                                  NaN
# 4385                                                  NaN
# 6607                                                  NaN
# 8700                                                  NaN
# ...                                                   ...
# 180708  "Bomb attack on mosque in Egypt's Sinai," BBC,...
# 180811  "Suicide bombers kill 11 in Iraq attack claime...
# 180942  "Official: Over 25 persons killed in booby-tra...
# 181537  "Al Houthi missile kills family of 10 in Sana...
# 181624  "Egypt: 10 killed in Cairo church attack by Da...
#
#                                                    scite2  \
# 1314                                                  NaN
# 2382                                                  NaN
# 4385                                                  NaN
# 6607                                                  NaN
# 8700                                                  NaN
# ...                                                   ...
# 180708  "Death toll in Sinai mosque bombing rises to 3...
# 180811  "Attack Kills At Least 11 Near Baghdad, IS Cla...
# 180942  "70% of Western Anbar Destroyed, Mosul Orphans...
# 181537                                                NaN
# 181624  "Gunmen attack church near Cairo, killing nine...
#
#                                                    scite3  \
# 1314                                                  NaN
# 2382                                                  NaN
# 4385                                                  NaN
# 6607                                                  NaN
# 8700                                                  NaN
# ...                                                   ...
# 180708  "Egypt Sinai mosque attack death toll rises to...
# 180811  "Xinhua: Suicide Attack Kills 8 In Southeast B...
# 180942                                                NaN
# 181537                                                NaN
# 181624  "Singapore: Gunman kills 9 in Egypt church att...
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  \
# 1314                        PGIS        1         1        0       1
# 2382                        PGIS        1         0        0       1
# 4385                        PGIS       -9        -9        0      -9
# 6607                        PGIS        0         1        1       1
# 8700                        PGIS        0         1        0       1
# ...                          ...      ...       ...      ...     ...
# 180708  START Primary Collection        0         0        0       0
# 180811  START Primary Collection        0         1        0       1
# 180942  START Primary Collection       -9        -9        0      -9
# 181537  START Primary Collection        0         0        0       0
# 181624  START Primary Collection        0         0        0       0
#
#                            related
# 1314                           NaN
# 2382                           NaN
# 4385                           NaN
# 6607                           NaN
# 8700                           NaN
# ...                            ...
# 180708                         NaN
# 180811                         NaN
# 180942                         NaN
# 181537                         NaN
# 181624  201712290002, 201712290003
#
# [1893 rows x 135 columns]

# %%
filter3 = filter2[filter2['nkill'] >=10]

# %%
filter4 = filter3[filter3['iyear'] >= 2000]

# %% [markdown]
# <h1>Data Aggregation</h1>

# %%
ME_terror = filter4.groupby(['longitude','latitude']).size().reset_index(name = 'incident_count')

# %%
ME_terror
# Out:
#      longitude   latitude  incident_count
# 0    -8.000000  31.633333               1
# 1    -7.610000  33.590000               1
# 2     0.138188  35.391899               1
# 3     1.988153  36.072919               1
# 4     2.344489  36.526708               1
# ..         ...        ...             ...
# 517  50.004524  26.554785               1
# 518  51.405190  35.724533               1
# 519  52.583610  29.591325               1
# 520  60.862701  29.483576               3
# 521  61.753754  26.079255               1
#
# [522 rows x 3 columns]

# %% [markdown]
# <h1>Visualization of GeoSpatial using FOLIUM</h1>

# %%
import folium 
from folium.plugins import HeatMap

# %%
heat_df = ME_terror[['longitude','latitude','incident_count']].values.tolist()

# %%
my_map = folium.Map(location = [30,40], zoom_start =4)

# %%
HeatMap(heat_df).add_to(my_map)

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c51f0d8770c402c80c24626f6bfff1b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c51f0d8770c402c80c24626f6bfff1b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c51f0d8770c402c80c24626f6bfff1b = L.map(
#                 &quot;map_7c51f0d8770c402c80c24626f6bfff1b&quot;,
#                 {
#                     center: [30.0, 40.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3579307c44b5866991d5e3aecace3e21 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3579307c44b5866991d5e3aecace3e21.addTo(map_7c51f0d8770c402c80c24626f6bfff1b);
#
#
#             var heat_map_63d784248c2013352479ead982c2a8dd = L.heatLayer(
#                 [[-8.0, 31.633333, 1.0], [-7.61, 33.59, 1.0], [0.138188, 35.391899, 1.0], [1.988153, 36.072919, 1.0], [2.344489, 36.526708, 1.0], [2.81464, 36.46298, 1.0], [3.055413, 36.763763, 3.0], [3.153934, 36.56522, 1.0], [3.594444, 36.562222, 2.0], [3.670848, 36.72398, 2.0], [3.809529, 36.672703, 1.0], [3.891396, 36.919552, 1.0], [3.902, 36.37489, 2.0], [4.049834, 36.716365, 1.0], [4.096944, 34.680833, 1.0], [4.462888, 36.077754, 1.0], [5.60722, 36.28611, 1.0], [5.751706, 36.813267, 1.0], [5.893085, 35.59901, 1.0], [6.166667, 35.55, 1.0], [6.83876, 36.673926, 1.0], [6.900388, 36.866618, 1.0], [7.146648, 35.43811, 1.0], [10.184214, 36.811427, 1.0], [10.855024, 33.819136, 1.0], [12.691492, 32.063988, 1.0], [12.9, 32.8, 1.0], [13.189067, 32.867867, 4.0], [14.622688, 32.407892, 1.0], [15.256008, 31.448914, 1.0], [15.724736, 31.395836, 1.0], [16.586681, 31.197586, 2.0], [20.151144, 32.069286, 7.0], [20.268871, 32.094952, 1.0], [20.451099, 32.42202, 1.0], [22.241188, 32.762238, 2.0], [27.969925, 27.058452, 1.0], [28.689863, 41.106178, 10.0], [29.696268, 30.762296, 1.0], [29.899403, 31.19829, 1.0], [30.999529, 30.787678, 1.0], [31.185192, 30.022924, 1.0], [31.334314, 30.084629, 2.0], [31.337257, 29.831976, 1.0], [31.379664, 31.039309, 1.0], [32.76754, 39.930771, 3.0], [32.805613, 39.798509, 1.0], [33.008587, 31.016779, 1.0], [33.617577, 30.608472, 1.0], [33.638188, 31.080795, 1.0], [33.644714, 30.699335, 1.0], [33.800865, 31.126646, 5.0], [34.076081, 30.886219, 1.0], [34.110425, 31.211645, 1.0], [34.117065, 31.212225, 3.0], [34.173178, 30.169854,